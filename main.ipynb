# %%
import pandas as pd
import numpy as np

# %%
folder_path = 'indi'

# %%
import os
os.listdir(folder_path)
# Out:
# ['1-2.xlsx', '3-4.xlsx', '5-54.xlsx', '55-59.xlsx', '6-12.xlsx']

# %%
excel_files = [file for file in os.listdir(folder_path) if file.endswith('.xlsx')]
combined_df = pd.concat([pd.read_excel(os.path.join(folder_path, file), skiprows=6) for file in excel_files])
# Out:
# c:\Users\Carlos\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\Carlos\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\Carlos\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\Carlos\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# ...

# %%
combined_df.dropna().head(30)
# Out:
#                                                            2023      2022  \
# 1                              1. CONTRA LAS PERSONAS  226761.0  212804.0
# 2                  1.1.-Homicidios dolosos/asesinatos    1692.0    1539.0
# 3       1.1.1.-Homicidios dolosos/asesinatos consu...     333.0     326.0
# 4                                       1.2.-Lesiones  118125.0  113704.0
# 5                   1.3.-Malos tratos ámbito familiar  101179.0   92695.0
# 6                      1.4.-Otros contra las personas    5765.0    4866.0
# 7                               2. CONTRA LA LIBERTAD  159113.0  143861.0
# 8       2.1.-Malos tratos habituales en el ámbito ...   17120.0   15647.0
# 9                       2.2.-Otros contra la libertad  141993.0  128214.0
# 11                             1. CONTRA LAS PERSONAS    1386.0    1269.0
# 12                 1.1.-Homicidios dolosos/asesinatos       7.0       3.0
# 13      1.1.1.-Homicidios dolosos/asesinatos consu...       1.0       0.0
# ...

# %%
pd.read_excel(r'.\indi\1-2.xlsx', skiprows=6)
# Out:
# c:\Users\Carlos\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
#                                                             2023      2022  \
# 0                                       Total Nacional       NaN       NaN
# 1                               1. CONTRA LAS PERSONAS  226761.0  212804.0
# 2                   1.1.-Homicidios dolosos/asesinatos    1692.0    1539.0
# 3        1.1.1.-Homicidios dolosos/asesinatos consu...     333.0     326.0
# 4                                        1.2.-Lesiones  118125.0  113704.0
# ..                                                 ...       ...       ...
# 553  (*) Se computan datos provenientes de la Polic...       NaN       NaN
# 554   (**) En agresiones sexuales con/sin penetraci...       NaN       NaN
# ...

# %%
# Cargar los archivos Excel
df1 = pd.read_excel('C:/Users/Carlos/Documents/GitHub/Criminality-Inssurances/indi/1-2.xlsx', header=5)
df2 = pd.read_excel('C:/Users/Carlos/Documents/GitHub/Criminality-Inssurances/indi/3-4.xlsx', header=5)
# Out:
# c:\Users\Carlos\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")
# c:\Users\Carlos\anaconda3\Lib\site-packages\openpyxl\styles\stylesheet.py:226: UserWarning: Workbook contains no default style, apply openpyxl's default
#   warn("Workbook contains no default style, apply openpyxl's default")

# %%
df1
# Out:
#                                             Unnamed: 0  Unnamed: 1  \
# 0                                                           2023.0
# 1                                       Total Nacional         NaN
# 2                               1. CONTRA LAS PERSONAS    226761.0
# 3                   1.1.-Homicidios dolosos/asesinatos      1692.0
# 4        1.1.1.-Homicidios dolosos/asesinatos consu...       333.0
# ..                                                 ...         ...
# 554  (*) Se computan datos provenientes de la Polic...         NaN
# 555   (**) En agresiones sexuales con/sin penetraci...         NaN
# 556                                                NaN         NaN
# 557                                           Fuente:          NaN
# 558                            Ministerio del Interior         NaN
#
#      Unnamed: 2  Unnamed: 3  Unnamed: 4  Unnamed: 5  Unnamed: 6  Unnamed: 7  \
# 0        2022.0      2021.0      2020.0      2019.0      2018.0      2017.0
# ...

# %%
# Unir los DataFrames por la columna de provincias
df_combined = pd.merge(df1, df2, on='Unnamed: 0', how='outer')

# %%
# Guardar el DataFrame combinado en un nuevo archivo Excel
df_combined.to_excel('archivo_combinado.xlsx', index=False)

# %%
df_combined
# Out:
#                        Unnamed: 0  Unnamed: 1_x  Unnamed: 2_x  Unnamed: 3_x  \
# 0                                        2023.0        2022.0        2021.0
# 1                  Total Nacional           NaN           NaN           NaN
# 2          1. CONTRA LAS PERSONAS      226761.0      212804.0      183590.0
# 3          1. CONTRA LAS PERSONAS        1386.0        1269.0        1027.0
# 4          1. CONTRA LAS PERSONAS        1638.0        1638.0        1316.0
# ..                            ...           ...           ...           ...
# 945      4. RELACIONES FAMILIARES           NaN           NaN           NaN
# 946      4. RELACIONES FAMILIARES           NaN           NaN           NaN
# 947      4. RELACIONES FAMILIARES           NaN           NaN           NaN
# 948      4. RELACIONES FAMILIARES           NaN           NaN           NaN
# 949      4. RELACIONES FAMILIARES           NaN           NaN           NaN
#
# ...
